# %%
pylab
# Out:
# Using matplotlib backend: Qt4Agg
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# A function $f$ is a rule that assigns to each element $x$ in a set $A$ exactly one element, called $f(x)$, in set $B$.
#
# * demain
# * independent variable
# * dependent variable

# %%
# absolute value
# %matplotlib inline
def f(x):
    if x >=0.0:
        return x
    else:
        return -x
  
x = linspace(-10,10,1000)

y=[]
for x_i in x:
    y.append(f(x_i))

plot(x,y,label='y=|x|')
legend()

# %%
# Symmetry
## even function
## odd function
x = linspace(-pi,pi,1000)
y1 = sin(x)
y2 = cos(x)


ax = gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))

xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi],
       [r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'])

yticks([-1, 0, +1],
       [r'$-1$', r'$0$', r'$+1$'])

plot(x,y1)
plot(x,y2)

# %%
def plot_xy(x,y):
    
    ax = gca()
    ax.spines['right'].set_color('none')
    ax.spines['top'].set_color('none')
    ax.xaxis.set_ticks_position('bottom')
    ax.spines['bottom'].set_position(('data',0))
    ax.yaxis.set_ticks_position('left')
    ax.spines['left'].set_position(('data',0))
    
    plot(x,y)

# %%
x = linspace(-pi,pi,1000)
y1 = sin(x)
y2 = cos(x)
plot_xy(x,y1)
plot_xy(x,y2)

# %% [markdown]
# Increasing and Decresing Functions
#
# * increasing: $f(x_1) < f(x_2)$ whenever $x_1 < x_2$
# * decreasing: $f(x_1) > f(x_2)$ whenever $x_1 < x_2$

# %% [markdown]
# ### 1.2 Mathematical Models: A Catalog of Essential Functions
#
# * Linear Models: $ y = f(x) = mx + b$
# * Polynomial Models: $ P(x)=a_nx^n + a_{n-1}x^{n-1}+...+a_2x^2+a_1x+a_0$
# * Power functions: $ f(x) = x^a $
# * Rational functions: $ f(x) = \frac{P(x)}{Q(x)}$
# * algebraic funtion
# * Trigonometric Functions
# * Exponential Functions

# %%
def f(x):
    return x**2 + x + 1
x = linspace(-3,3,100)
y = f(x)
plot_xy(x,y)

# %%
def f(x):
    return -2*x**2 + 3*x + 1
x = linspace(-3,3,100)
y = f(x)
plot_xy(x,y)

# %%
def f(x):
    return x
x = linspace(-3,3,100)
y = f(x)
plot_xy(x,y)

# %%
def f(x):
    return x**2
x = linspace(-3,3,100)
y = f(x)
plot_xy(x,y)

# %%
def f(x):
    return x**3
x = linspace(-3,3,100)
y = f(x)
plot_xy(x,y)

# %%
def f(x):
    return x**4
x = linspace(-3,3,100)
y = f(x)
plot_xy(x,y)

# %%
def f(x):
    return x**5
x = linspace(-3,3,100)
y = f(x)
plot_xy(x,y)

# %%
def f4(x):
    return x**4
def f5(x):
    return x**5
def f6(x):
    return x**6

x = linspace(-1.2,1.2,100)
y4 = f4(x)
y5 = f5(x)
y6 = f6(x)

plot_xy(x,y4)
plot_xy(x,y5)
plot_xy(x,y6)

# %%
def f(x):
    return 1/x
x = linspace(-3,3,100)
y = f(x)
plot_xy(x,y)

# %%
def f(x):
    return (2*x**4 - x**2 + 1)/(x**2 -4)
x = linspace(-4,4,100)
y = f(x)
plot_xy(x,y)

# %%
def f(x):
    return sin(x)
x = linspace(-2*pi,2*pi,100)
y = f(x)
plot_xy(x,y)

# %%
def f(x):
    return cos(x)
x = linspace(-2*pi,2*pi,100)
y = f(x)
plot_xy(x,y)

# %%
def f(x):
    return 2**x
x = linspace(-2,2,100)
y = f(x)
plot_xy(x,y)

# %%
def f(x):
    return 0.5**x
x = linspace(-2,2,100)
y = f(x)
plot_xy(x,y)

# %%
def f(x):
    return x**(1.0/2)
x = linspace(-2,2,10000)
y = f(x)
plot_xy(x,y)
# Out:
# -c:2: RuntimeWarning: invalid value encountered in sqrt

# %%
def f(x):
    return (1+x)/(1-x**(1.0/2))
x = linspace(1.1,5,10000)
y = f(x)
plot_xy(x,y)

# %%
import math
def f(x):
    return x
x = linspace(1.1,5,10000)
y = f(x)
y1 = f(x+2)
plot_xy(x,y)
plot_xy(x,y1)

# %%
import math
def f(x):
    return cos(x)
x = linspace(-pi,2*pi,10000)
y = f(x)
y1 = f(x+pi/2)
plot_xy(x,y)
plot_xy(x,y1)

# %%
import math
def f(x):
    return cos(x)
x = linspace(-pi,2*pi,10000)
y = f(x)
y1 = f(2*x)
y2 = 0.5*f(x)
plot_xy(x,y)
plot_xy(x,y1)
plot_xy(x,y2)

# %%
def f(x):
    return x**0.5 - 1
x = linspace(-2,2,10000)
y = f(x)
plot_xy(x,y)

# %%
def f(x):
    return (x -1)**0.5
x = linspace(-2,2,10000)
y = f(x)
plot_xy(x,y)

# %%
def f(x):
    return -sqrt(x)
x = linspace(-2,2,10000)
y = f(x)
plot_xy(x,y)

# %%
def f(x):
    return 2*sqrt(x)
x = linspace(-2,2,10000)
y = f(x)
plot_xy(x,y)

# %%
def f(x):
    return sqrt(-x)
x = linspace(-2,2,10000)
y = f(x)
plot_xy(x,y)

# %%
def f(x):
    return (4 - x*x)**0.5
x = linspace(-2,2,10000)
y = f(x)
plot(x,y)

# %%
def f(x):
    return sin(x) + 0.01*cos(100*x)
x = linspace(-0.1,0.1,10000)
y = f(x)
plot(x,y)

# %%
def f(x):
    return 1./(1-x)
x = linspace(-5,5,100)
y = f(x)
plot(x,y)

# %%
def f(x):
    return 3-2**x
x = linspace(-5,5,100)
y = f(x)
plot(x,y)

# %% [markdown]
# ### The meaning of e
#
# $  (a^x)^、=a^x lna$
#
# let $ a^x lna = 1 $ when $ x=0$
#
# =>  $ lna = 1$, let $a = e$

# %%
def f(x):
    return e**x
x = linspace(-2,2,100)
y = f(x)
plot(x,y)

# %%
def f(x):
    return e**(-x)
x = linspace(-2,2,100)
y = f(x)
plot(x,y)

# %%
def f(x):
    return 0.5*e**(-x)
x = linspace(-2,2,100)
y = f(x)
plot(x,y)

# %%
def f(x):
    return log(x)
x = linspace(-2,200,10000)
y = f(x)
plot(x,y)
plot(x,sqrt(x))
# Out:
# -c:2: RuntimeWarning: divide by zero encountered in log

# %%
# Out:
# 1.0
